# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
data = {
    'Weather': ['Sunny', 'Sunny', 'Sunny', 'Sunny', 'Sunny', 'Rainy', 'Rainy', 'Rainy', 'Rainy', 'Rainy'],
    'Humidity': ['Normal', 'Normal', 'Normal', 'High', 'High', 'High', 'High', 'Low', 'Low', 'Low'],
    'Wind': ['Weak', 'Weak', 'Strong', 'Weak', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong', 'Weak'],
    'Play': ['No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
}
df = pd.DataFrame(data)
df
# Out:
#   Weather Humidity    Wind Play
# 0   Sunny   Normal    Weak   No
# 1   Sunny   Normal    Weak   No
# 2   Sunny   Normal  Strong   No
# 3   Sunny     High    Weak   No
# 4   Sunny     High  Strong   No
# 5   Rainy     High  Strong  Yes
# 6   Rainy     High  Strong  Yes
# 7   Rainy      Low    Weak  Yes
# 8   Rainy      Low  Strong  Yes
# 9   Rainy      Low    Weak  Yes

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

data = {
    'Weather': ['Sunny', 'Sunny', 'Sunny', 'Sunny', 'Sunny', 'Rainy', 'Rainy', 'Rainy', 'Rainy', 'Rainy'],
    'Humidity': ['Normal', 'Normal', 'Normal', 'High', 'High', 'High', 'High', 'Low', 'Low', 'Low'],
    'Wind': ['Weak', 'Weak', 'Strong', 'Weak', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong', 'Weak'],
    'Play': ['No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
}
df = pd.DataFrame(data)


le = LabelEncoder() # encoding
df['Weather'] = le.fit_transform(df['Weather'])
df['Humidity'] = le.fit_transform(df['Humidity'])
df['Wind'] = le.fit_transform(df['Wind'])

# set feature and target
features = ['Weather', 'Humidity', 'Wind']
target = 'Play'

# decision tree classifier
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(df[features], df[target])
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Train the decision tree classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(10, 7))
plot_tree(clf, feature_names=features, class_names=df[target].unique(), filled=True)
plt.show()
